# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Brute-force" data-toc-modified-id="Brute-force-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Brute force</a></span></li><li><span><a href="#Using-mousai" data-toc-modified-id="Using-mousai-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Using mousai</a></span></li></ul></div>

# %% [markdown]
# According to [wikipedia](https://en.wikipedia.org/wiki/Duffing_equation#Frequency_response), the Duffing frequency response can be described using the following analytical form:
#
# $\begin{align}
# \left[ \left( \omega^2-\alpha-\frac{3}{4}\beta z^2 \right)^2 + \left( \delta\omega \right)^2 \right] z^2 = \gamma^2
# \end{align}$

# %% [markdown]
# # Brute force

# %%
import matplotlib.pyplot as plt
import numpy as np

xrange = np.arange(0, 2, 1e-3)
yrange = np.arange(0, 14, 1e-3)
w, z = np.meshgrid(xrange,yrange)

alpha=1
delta=0.1
gamma=1

RHS = gamma**2
def LHS(beta):
    return z**2* ( (w**2-alpha-3/4*beta*z**2)**2 +(delta*w)**2 )

def sol(beta):
    return LHS(beta)-RHS

# %%
import matplotlib
cmap = matplotlib.cm.get_cmap('coolwarm')

# %%
betas = [-0.003,0,0.01,0.04]
myws,myzs = [], []
for i,beta in enumerate(betas):
    cs = plt.contour(w,z,sol(beta), [0],colors=[cmap(i/(len(betas)-1))])
    plt.plot([],[],label=r'$\beta={:+.3f}$'.format(beta),c=cmap(i/(len(betas)-1)))
    # Extracting the data
    p = cs.collections[0].get_paths()[0]
    v = p.vertices
    xx,yy = v[:,0],v[:,1]
#     xx,yy = list(zip(*sorted(zip(xx,yy))))
    myws.append(xx)
    myzs.append(yy)

plt.xlabel(r'$\omega$')
plt.ylabel(r'$z$')
plt.legend()

# %%
for i,(beta,ww,zz) in enumerate(zip(betas,myws,myzs)):
    plt.plot(ww,zz,label=r'$\beta={:+.3f}$'.format(beta),c=cmap(i/(len(betas)-1)))
#     plt.plot(ww,zz,label=r'$\beta={:+.3f}$'.format(beta),c=cmap(beta/(abs(min(betas)-max(betas)))))
    # for normalized values

plt.xlabel(r'Drive frequency $\omega$')
plt.ylabel(r'Amplitude responde $x$')
plt.legend()

# %%
for i,(beta,ww,zz) in enumerate(zip(betas,myws,myzs)):
    plt.plot(ww,np.gradient(ww),label=r'$\beta={:+.3f}$'.format(beta),c=cmap(i/(len(betas)-1)))
plt.axhline(0,c='k')
plt.ylim(-1e-4,2e-4)
# plt.gca().set_ylim(bottom=-1e-4)
plt.legend()

# %% [markdown]
# We can use the above gradient to color the regions of instability

# %% [markdown]
# # Using mousai

# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import mousai as ms
from scipy import pi, sin

# %%
# Define our function (Python)
def duff_osc_ss(x, params,alpha=1,beta=0.0,gamma=1,delta=0.1):
    omega = params['omega']
    t = params['cur_time']
    xd = np.array([[x[1]],
                   [-alpha*x[0] - beta** x[0]**3 - delta* x[1] + gamma * sin(omega * t)]])
    return xd

# %%
omegal = np.linspace(2.5,0,101)
ampl = sp.zeros_like(omegal)
ampl[:] = np.nan
t, x, e, amps, phases = ms.hb_time(duff_osc_ss, num_variables=2,
                                 omega=2.5, eqform='first_order', num_harmonics=1)
for i, freq in enumerate(omegal):
    # Here we try to obtain solutions, but if they don't work,
    # we ignore them by inserting `np.nan` values.
    x = x - np.average(x)
    try:
        t, x, e, amps, phases = ms.hb_time(duff_osc_ss, x0=x,
                 omega=freq, eqform='first_order', num_harmonics=1)
        ampl[i] = amps[0]
    except:
        ampl[i] = np.nan
    if np.isnan(ampl[i]):
        break
# Out:
# /home/feschmidt/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in double_scalars
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-1c62eca354c6> in <module>()
#       3 ampl[:] = np.nan
#       4 t, x, e, amps, phases = ms.hb_time(duff_osc_ss, num_variables=2,
# ----> 5                                  omega=2.5, eqform='first_order', num_harmonics=1)
#       6 for i, freq in enumerate(omegal):
#       7     # Here we try to obtain solutions, but if they don't work,
#
# /usr/local/lib/python3.6/dist-packages/mousai/har_bal.py in hb_time(sdfunc, x0, omega, method, num_harmonics, num_variables, eqform, params, realify, **kwargs)
#     284
#     285     try:
# --> 286         x = globals()[method](hb_err, x0, **kwargs)
#     287     except:
#     288         x = x0  # np.full([x0.shape[0],x0.shape[1]],np.nan)
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/nonlin.py in newton_krylov(F, xin, iter, rdiff, method, inner_maxiter, inner_M, outer_k, verbose, maxiter, f_tol, f_rtol, x_tol, x_rtol, tol_norm, line_search, callback, **kw)
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/nonlin.py in nonlin_solve(F, x0, jacobian, iter, verbose, maxiter, f_tol, f_rtol, x_tol, x_rtol, tol_norm, line_search, callback, full_output, raise_exception)
#     310         # The tolerance, as computed for scipy.sparse.linalg.* routines
#     311         tol = min(eta, eta*Fx_norm)
# --> 312         dx = -jacobian.solve(Fx, tol=tol)
#     313
#     314         if norm(dx) == 0:
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/nonlin.py in solve(self, rhs, tol)
#    1462             sol, info = self.method(self.op, rhs, **self.method_kw)
#    1463         else:
# -> 1464             sol, info = self.method(self.op, rhs, tol=tol, **self.method_kw)
#    1465         return sol
#    1466
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/linalg/isolve/lgmres.py in lgmres(A, b, x0, tol, maxiter, M, callback, inner_m, outer_k, outer_v, store_outer_Av, prepend_outer_v, atol)
#     189                                                atol=ptol,
#     190                                                outer_v=outer_v,
# --> 191                                                prepend_outer_v=prepend_outer_v)
#     192             y *= inner_res_0
#     193             if not np.isfinite(y).all():
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/linalg/isolve/_gcrotmk.py in _fgmres(matvec, v0, m, atol, lpsolve, rpsolve, cs, outer_v, prepend_outer_v)
#     105
#     106         if w is None:
# --> 107             w = lpsolve(matvec(z))
#     108         else:
#     109             # w is clobbered below
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/linalg/interface.py in matvec(self, x)
#     225             raise ValueError('dimension mismatch')
#     226
# --> 227         y = self._matvec(x)
#     228
#     229         if isinstance(x, np.matrix):
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/linalg/interface.py in _matvec(self, x)
#     477
#     478     def _matvec(self, x):
# --> 479         return self.__matvec_impl(x)
#     480
#     481     def _rmatvec(self, x):
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/nonlin.py in matvec(self, v)
#    1455         r = (self.func(self.x0 + sc*v) - self.f0) / sc
#    1456         if not np.all(np.isfinite(r)) and np.all(np.isfinite(v)):
# -> 1457             raise ValueError('Function returned non-finite results')
#    1458         return r
#    1459
#
# ValueError: Function returned non-finite results

# %%
plt.plot(omega,amp, label='Up sweep')
plt.plot(omegal,ampl, label='Down sweep')
plt.legend()
plt.title('Amplitude versus frequency for Duffing Oscillator')
plt.xlabel('Driving frequency $\\omega$')
plt.ylabel('Amplitude')
plt.grid()
